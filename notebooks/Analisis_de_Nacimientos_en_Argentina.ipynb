# %% [markdown]
# > # Introduccion
#
# En este proyecto, se tiene como objetivo analizar el archivo "**[nacimientos2023](https://www.datos.gob.ar/dataset/salud-nacidos-vivos-registrados-por-jurisdiccion-residencia-madre---republica-argentina/archivo/salud_40e722b8-72eb-49a0-89dc-5ee174bf63b4)**", el cual contiene datos de nacidos vivos registrados en la Republica Argentina, el archivo pertenece al Ministerio de Salud. Dirección de Estadística e Información en Salud (DEIS).

# %% [markdown]
# ## Importar librerias y cargar dataset
# A continuación se importan las librerías necesarias y se carga el archivo CSV.

# %%
import pandas as pd
from google.colab import files

# %%
df = pd.read_csv("nacimientos2023.csv", sep=";")
df.head()
# Out:
#    anio  jurisdiccion_de_residencia_id    jurisdicion_residencia_nombre  \
# 0  2023                              2  Ciudad Autónoma de Buenos Aires
# 1  2023                              2  Ciudad Autónoma de Buenos Aires
# 2  2023                              2  Ciudad Autónoma de Buenos Aires
# 3  2023                              2  Ciudad Autónoma de Buenos Aires
# 4  2023                              2  Ciudad Autónoma de Buenos Aires
#
#   edad_madre_grupo                  instruccion_madre  tipo_de_parto_id  \
# 0        4.25 a 29  4.Secundaria/Polimodal Incompleta                 1
# 1        4.25 a 29  4.Secundaria/Polimodal Incompleta                 1
# 2        4.25 a 29  4.Secundaria/Polimodal Incompleta                 1
# 3        4.25 a 29  4.Secundaria/Polimodal Incompleta                 1
# 4        4.25 a 29  4.Secundaria/Polimodal Incompleta                 1
#
#   tipo_de_parto_nombre semana_gestacion intervalo_peso_al_nacer  sexo_id  \
# 0               Simple        6.37 a 41         8.De 3500 y más        1
# 1               Simple        6.37 a 41           5.2000 a 2499        1
# 2               Simple        6.37 a 41           6.2500 a 2999        1
# 3               Simple        6.37 a 41           7.3000 a 3499        1
# 4               Simple        3.24 a 27           3.1000 a 1499        1
#
#         Sexo  nacimientos_cantidad
# 0  masculino                   137
# 1  masculino                     3
# 2  masculino                    36
# 3  masculino                   111
# 4  masculino                     1

# %% [markdown]
# ## Expansion de registros
# Luego de un primer analisis del archivo se puede observar como la Serie **nacimientos_cantidad** es la responsable de enumerar cuantos registros cumplen las mismas caracteristicas, la cual, hay que expander para que cada fila sea igual a un dato

# %%
df = df.loc[
    df.index.repeat(df["nacimientos_cantidad"])
].reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460902 entries, 0 to 460901
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   anio                           460902 non-null  int64
#  1   jurisdiccion_de_residencia_id  460902 non-null  int64
#  2   jurisdicion_residencia_nombre  460688 non-null  object
#  3   edad_madre_grupo               460902 non-null  object
#  4   instruccion_madre              460902 non-null  object
#  5   tipo_de_parto_id               460902 non-null  int64
#  6   tipo_de_parto_nombre           460902 non-null  object
#  7   semana_gestacion               460902 non-null  object
#  8   intervalo_peso_al_nacer        460902 non-null  object
#  9   sexo_id                        460902 non-null  int64
#  10  Sexo                           460902 non-null  object
#  11  nacimientos_cantidad           460902 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 42.2+ MB

# %% [markdown]
# ## Exploracion inicial del dataset
#
# Antes de realizar análisis más profundos, es importante explorar las principales variables del dataset para entender su contenido, tipo de datos y posibles inconsistencias.
# Se analizarán columnas como:
# - `jurisdicion_residencia_nombre`: Ubicacion geografica
# - `edad_madre_grupo`: Rango de edad de la madre al momento del nacimiento.
# - `instruccion_madre`: Nivel educativo de la madre.

# %%
df["edad_madre_grupo"].value_counts()
# Out:
# edad_madre_grupo
# 4.25 a 29            115487
# 5.30 a 34            106505
# 3.20 a 24            102280
# 6.35 a 39             68671
# 2.15 a 19             39504
# 7.40 a 44             21125
# 9.Sin especificar      4263
# 8.De 45 y más          2011
# 1.Menor de 15          1056
# Name: count, dtype: int64

# %%
df['jurisdicion_residencia_nombre'].value_counts()
# Out:
# jurisdicion_residencia_nombre
# Buenos Aires                                             162380
# Córdoba                                                   38126
# Santa Fe                                                  37635
# Ciudad Autónoma de Buenos Aires                           23988
# Mendoza                                                   20036
# Misiones                                                  18932
# Tucumán                                                   18537
# Salta                                                     16974
# Chaco                                                     16769
# Corrientes                                                14253
# Entre Ríos                                                14073
# Santiago del Estero                                       11871
# San Juan                                                   9795
# Formosa                                                    8250
# Río Negro                                                  7375
# Jujuy                                                      7365
# Neuquén                                                    6891
# Chubut                                                     5434
# San Luis                                                   4963
# Catamarca                                                  4248
# La Rioja                                                   4184
# La Pampa                                                   3238
# Santa Cruz                                                 3139
# Tierra del Fuego, Antártida e Islas del Atlántico Sur      1440
# Sin Información                                             792
# Name: count, dtype: int64

# %%
df['tipo_de_parto_nombre'].value_counts()
# Out:
# tipo_de_parto_nombre
# Simple         450531
# Multiple         9000
# Desconocido      1371
# Name: count, dtype: int64

# %%
df['semana_gestacion'].value_counts()
# Out:
# semana_gestacion
# 6.37 a 41            412326
# 5.32 a 36             37443
# 4.28 a 31              3954
# 8.Sin especificar      3543
# 7.42 y más             1712
# 3.24 a 27              1560
# 2.22 a 23               313
# 1.Menos de 22            51
# Name: count, dtype: int64

# %%
df["instruccion_madre"].value_counts()
# Out:
# instruccion_madre
# 5.Secundaria/Polimodal Completa         158924
# 4.Secundaria/Polimodal Incompleta       107822
# 7.Terciaria/Universitaria Completa       70604
# 3.Primaria/C. EGB Completa               54908
# 6.Terciaria/Universitaria Incompleta     31665
# 8.Sin especificar                        26131
# 2.Primaria/C. EGB Incompleta              9961
# 1.Sin instrucción                          887
# Name: count, dtype: int64

# %% [markdown]
# ## Inconsistencias en el nivel educativo de madres adolescentes

# %%
edad_menor_a_20 = df[(df['edad_madre_grupo'] == "2.15 a 19") | (df["edad_madre_grupo"] == "1.Menor de 15")]
edad_menor_a_20['instruccion_madre'].value_counts()
# Out:
# instruccion_madre
# 4.Secundaria/Polimodal Incompleta       21657
# 5.Secundaria/Polimodal Completa          8501
# 3.Primaria/C. EGB Completa               5938
# 8.Sin especificar                        2413
# 2.Primaria/C. EGB Incompleta             1288
# 6.Terciaria/Universitaria Incompleta      569
# 1.Sin instrucción                         103
# 7.Terciaria/Universitaria Completa         91
# Name: count, dtype: int64

# %%
pd.crosstab(
    edad_menor_a_20["edad_madre_grupo"],
    edad_menor_a_20["instruccion_madre"]
)
# Out:
# instruccion_madre  1.Sin instrucción  2.Primaria/C. EGB Incompleta  \
# edad_madre_grupo
# 1.Menor de 15                      8                           117
# 2.15 a 19                         95                          1171
#
# instruccion_madre  3.Primaria/C. EGB Completa  \
# edad_madre_grupo
# 1.Menor de 15                             237
# 2.15 a 19                                5701
#
# instruccion_madre  4.Secundaria/Polimodal Incompleta  \
# edad_madre_grupo
# 1.Menor de 15                                    580
# 2.15 a 19                                      21077
#
# instruccion_madre  5.Secundaria/Polimodal Completa  \
# edad_madre_grupo
# 1.Menor de 15                                   37
# 2.15 a 19                                     8464
#
# instruccion_madre  6.Terciaria/Universitaria Incompleta  \
# edad_madre_grupo
# 1.Menor de 15                                         0
# 2.15 a 19                                           569
#
# instruccion_madre  7.Terciaria/Universitaria Completa  8.Sin especificar
# edad_madre_grupo
# 1.Menor de 15                                       0                 77
# 2.15 a 19                                          91               2336

# %% [markdown]
# Al analizar el grupo de madres de **15 a 19 años**, se identificaron **92 casos (≈0,3 %)** que presentan **nivel universitario completo**.
#
# Esta clasificación no resulta compatible con las trayectorias educativas esperables para dicho rango etario, por lo que se interpreta como una posible **inconsistencia en la variable `instruccion_madre`**, atribuible a definiciones administrativas o errores de carga de datos.
#
# Es importante destacar que, dado que representan una **proporción muy baja** del total de registros, estas inconsistencias **no afectan los patrones generales** observados en el análisis.

# %%
menora20_Terciario_completo = edad_menor_a_20[edad_menor_a_20['instruccion_madre'] == '7.Terciaria/Universitaria Completa']
menora20_Terciario_completo.head()
# Out:
#        anio  jurisdiccion_de_residencia_id jurisdicion_residencia_nombre  \
# 15531  2023                             22                         Chaco
# 15532  2023                             22                         Chaco
# 15533  2023                             22                         Chaco
# 15534  2023                             22                         Chaco
# 15535  2023                             22                         Chaco
#
#       edad_madre_grupo                   instruccion_madre  tipo_de_parto_id  \
# 15531        2.15 a 19  7.Terciaria/Universitaria Completa                 1
# 15532        2.15 a 19  7.Terciaria/Universitaria Completa                 1
# 15533        2.15 a 19  7.Terciaria/Universitaria Completa                 1
# 15534        2.15 a 19  7.Terciaria/Universitaria Completa                 1
# 15535        2.15 a 19  7.Terciaria/Universitaria Completa                 1
#
#       tipo_de_parto_nombre semana_gestacion intervalo_peso_al_nacer  sexo_id  \
# 15531               Simple        5.32 a 36           6.2500 a 2999        1
# 15532               Simple        6.37 a 41           5.2000 a 2499        1
# 15533               Simple        6.37 a 41           6.2500 a 2999        1
# 15534               Simple        6.37 a 41           6.2500 a 2999        1
# 15535               Simple        6.37 a 41           6.2500 a 2999        1
#
#             Sexo  nacimientos_cantidad
# 15531  masculino                     1
# 15532  masculino                     1
# 15533  masculino                     3
# 15534  masculino                     3
# 15535  masculino                     3

# %%
menora20_Terciario_completo['jurisdicion_residencia_nombre'].value_counts()
# Out:
# jurisdicion_residencia_nombre
# Buenos Aires                       25
# Chaco                              21
# Ciudad Autónoma de Buenos Aires     6
# Salta                               6
# Santa Fe                            5
# Mendoza                             4
# Entre Ríos                          4
# Santiago del Estero                 3
# Neuquén                             3
# Misiones                            3
# Chubut                              3
# Río Negro                           2
# Córdoba                             2
# Corrientes                          1
# La Pampa                            1
# Formosa                             1
# La Rioja                            1
# Name: count, dtype: int64

# %% [markdown]
# Las inconsistencias en el nivel educativo de madres adolescentes no se distribuyen homogéneamente entre provincias. En particular, **Chaco** presenta una concentración inusualmente elevada de registros con nivel terciario/universitario completo en menores de 20 años, en relación con su volumen total de nacimientos.

# %% [markdown]
# ##¿En que provincia se concentran los embarazos adolescentes?

# %%
edad_menor_a_20['jurisdicion_residencia_nombre'].value_counts()
# Out:
# jurisdicion_residencia_nombre
# Buenos Aires                                             13452
# Santa Fe                                                  3593
# Córdoba                                                   3132
# Misiones                                                  2667
# Chaco                                                     2194
# Salta                                                     1922
# Tucumán                                                   1628
# Corrientes                                                1596
# Mendoza                                                   1549
# Santiago del Estero                                       1340
# Entre Ríos                                                1288
# Formosa                                                   1185
# San Juan                                                  1014
# Ciudad Autónoma de Buenos Aires                            619
# Río Negro                                                  509
# Jujuy                                                      481
# Neuquén                                                    451
# San Luis                                                   366
# Catamarca                                                  354
# Chubut                                                     332
# La Rioja                                                   309
# Santa Cruz                                                 252
# La Pampa                                                   215
# Tierra del Fuego, Antártida e Islas del Atlántico Sur       66
# Sin Información                                             18
# Name: count, dtype: int64

# %%
tasa_menor20 = (
    edad_menor_a_20.groupby('jurisdicion_residencia_nombre').size()
    /
    df.groupby('jurisdicion_residencia_nombre').size()
) * 100

tasa_menor20.sort_values(ascending=False)
# Out:
# jurisdicion_residencia_nombre
# Formosa                                                  14.363636
# Misiones                                                 14.087260
# Chaco                                                    13.083666
# Salta                                                    11.323200
# Santiago del Estero                                      11.288013
# Corrientes                                               11.197643
# San Juan                                                 10.352221
# Santa Fe                                                  9.546964
# Entre Ríos                                                9.152277
# Tucumán                                                   8.782435
# Catamarca                                                 8.333333
# Buenos Aires                                              8.284271
# Córdoba                                                   8.214866
# Santa Cruz                                                8.028034
# Mendoza                                                   7.731084
# La Rioja                                                  7.385277
# San Luis                                                  7.374572
# Río Negro                                                 6.901695
# La Pampa                                                  6.639901
# Neuquén                                                   6.544769
# Jujuy                                                     6.530889
# Chubut                                                    6.109680
# Tierra del Fuego, Antártida e Islas del Atlántico Sur     4.583333
# Ciudad Autónoma de Buenos Aires                           2.580457
# Sin Información                                           2.272727
# dtype: float64

# %% [markdown]
# El análisis por tasas revela que, aun cuando las provincias más pobladas concentran la mayor cantidad absoluta de nacimientos, las tasas más elevadas de maternidad adolescente se observan en provincias del NEA y NOA, particularmente `Formosa`, `Misiones` y `Chaco`, donde de cada 100 nacimientos, ≈14 pertenecen a mujeres inferior a 20 años

# %% [markdown]
# ### Graficos:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tasa_df = tasa_menor20.reset_index()
tasa_df.columns = ['Provincia', 'Tasa <20 años']

plt.figure(figsize=(12,6))
sns.barplot(data=tasa_df, x='Tasa <20 años', y='Provincia', palette='viridis', orient='h')
plt.title('Tasa de maternidad adolescente por provincia')
plt.xlabel('Porcentaje de nacimientos <20 años')
plt.ylabel('Provincia')
# Out:
# /tmp/ipython-input-4122372486.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tasa_df, x='Tasa <20 años', y='Provincia', palette='viridis', orient='h')
# Text(0, 0.5, 'Provincia')

# %%
import geopandas as gpd

mapa = gpd.read_file("provinciaPolygon.shp")
mapa = mapa.to_crs(epsg=4326)

tasa_df['Provincia'] = tasa_df['Provincia'].str.upper()
mapa['nam'] = mapa['nam'].str.upper()

# %%
set_mapa = set(mapa['nam'])
set_datos = set(tasa_df['Provincia'])

set_mapa - set_datos
# Out:
# {'CIUDAD AUTÃ³NOMA DE BUENOS AIRES',
#  'CÃ³RDOBA',
#  'ENTRE RÃ\xadOS',
#  'NEUQUÃ©N',
#  'RÃ\xadO NEGRO',
#  'TIERRA DEL FUEGO, ANTÃ¡RTIDA E ISLAS DEL ATLÃ¡NTICO SUR',
#  'TUCUMÃ¡N'}

# %%
reemplazos_mapa = {
    'CIUDAD AUTÃ³NOMA DE BUENOS AIRES': 'CIUDAD AUTÓNOMA DE BUENOS AIRES',
    'CÃ³RDOBA': 'CÓRDOBA',
    'ENTRE RÃ\xadOS': 'ENTRE RÍOS',
    'NEUQUÃ©N': 'NEUQUÉN',
    'RÃ\xadO NEGRO': 'RÍO NEGRO',
    'TIERRA DEL FUEGO, ANTÃ¡RTIDA E ISLAS DEL ATLÃ¡NTICO SUR':
        'TIERRA DEL FUEGO, ANTÁRTIDA E ISLAS DEL ATLÁNTICO SUR',
    'TUCUMÃ¡N': 'TUCUMÁN'
}

mapa['nam'] = mapa['nam'].replace(reemplazos_mapa)
mapa['nam'] = mapa['nam'].str.upper().str.strip()
tasa_df['Provincia'] = tasa_df['Provincia'].str.upper().str.strip()

# %%
set(mapa['nam']) - set(tasa_df['Provincia'])
set(tasa_df['Provincia']) - set(mapa['nam'])
# Out:
# {'SIN INFORMACIÓN'}

# %%
mapa_tasa = mapa.merge(
    tasa_df,
    left_on='nam',
    right_on='Provincia',
    how='left'
)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8,10))

mapa_tasa.plot(
    column='Tasa <20 años',
    cmap='viridis',
    linewidth=0.6,
    edgecolor='black',
    legend=True,
    ax=ax,
    missing_kwds={
        "color": "lightgrey",
        "label": "Sin datos"
    }
)

ax.set_title(
    'Tasa de maternidad adolescente por provincia\nArgentina',
    fontsize=14,
    weight='bold'
)

ax.axis('off')
plt.tight_layout()

# %% [markdown]
# ## ¿Qué tan asociado está el nivel educativo con la probabilidad de maternidad adolescente?

# %%
edad_menor_a_20['instruccion_madre'].value_counts(normalize=True) *100
# Out:
# instruccion_madre
# 4.Secundaria/Polimodal Incompleta       53.394970
# 5.Secundaria/Polimodal Completa         20.959073
# 3.Primaria/C. EGB Completa              14.640039
# 8.Sin especificar                        5.949211
# 2.Primaria/C. EGB Incompleta             3.175542
# 6.Terciaria/Universitaria Incompleta     1.402860
# 1.Sin instrucción                        0.253945
# 7.Terciaria/Universitaria Completa       0.224359
# Name: proportion, dtype: float64

# %% [markdown]
# Interpretación
#
# - Se observa una **relación inversa clara**: a menor nivel educativo, mayor es la probabilidad de maternidad adolescente.
# - Las mujeres que **no completaron la secundaria** presentan la probabilidad más alta (~20%), mientras que quienes **completaron estudios terciarios o universitarios** tienen casi nula probabilidad.
# - Algunos casos en categorías altas pueden deberse a inconsistencias en la carga de datos, por lo que la interpretación se centra en **el patrón general**.

# %% [markdown]
# ###Grafico:

# %%
prob_adolescente_por_educ = (
    df[df['edad_madre_grupo'].isin(["1.Menor de 15", "2.15 a 19"])]
    .groupby('instruccion_madre')
    .size()
    /
    df.groupby('instruccion_madre').size()
) * 100

import matplotlib.pyplot as plt
import seaborn as sns

plot_data = prob_adolescente_por_educ.reset_index()
plot_data.columns = ['Nivel educativo', 'Probabilidad (%)']
plot_data = plot_data.sort_values(by='Probabilidad (%)', ascending=False)


plt.figure(figsize=(10,6))
sns.barplot(
    x='Probabilidad (%)',
    y='Nivel educativo',
    data=plot_data,
    palette='viridis'
)
plt.title('Probabilidad de maternidad adolescente según nivel educativo')
plt.xlabel('Probabilidad de ser madre <20 (%)')
plt.ylabel('Nivel educativo')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3529026365.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
import seaborn as sns

prob_por_educ_edad = (
    df
    .groupby(['instruccion_madre', 'edad_madre_grupo'])
    .size()
    .reset_index(name='conteo')
)

prob_por_educ_edad['Probabilidad (%)'] = (
    prob_por_educ_edad['conteo']
    / prob_por_educ_edad.groupby('instruccion_madre')['conteo'].transform('sum')
    * 100
)

plot_data = prob_por_educ_edad.pivot(
    index='instruccion_madre',
    columns='edad_madre_grupo',
    values='Probabilidad (%)'
)

plt.figure(figsize=(12,6))
sns.heatmap(
    plot_data,
    annot=True,
    fmt='.1f',
    cmap='viridis'
)

plt.title('Distribución porcentual de maternidad por grupo etario y nivel educativo')
plt.xlabel('Grupo etario')
plt.ylabel('Nivel educativo')
plt.tight_layout()
plt.show()

# %%
plot_data.plot(
    kind='barh',
    stacked=True,
    figsize=(12,6),
    colormap='magma'
)

plt.title('Distribución de la maternidad por grupo etario según nivel educativo')
plt.xlabel('Porcentaje (%)')
plt.ylabel('Nivel educativo')
plt.legend(title='Grupo etario', bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Exploracion mediante K-means
#
# En esta etapa se aplica un enfoque de clustering no supervisado (K-means) con el objetivo de identificar patrones y perfiles maternos a partir de variables sociodemográficas, principalmente edad y nivel educativo. Este análisis exploratorio busca agrupar observaciones con características similares, permitiendo observar regularidades y contrastes que no son evidentes mediante el análisis descriptivo tradicional. Los clusters obtenidos no representan categorías causales, sino agrupaciones estadísticas que facilitan la interpretación de estructuras subyacentes en los datos.

# %%
df_cluster = df[
    ['edad_madre_grupo',
     'instruccion_madre', ]
].copy()
df_encoded = pd.get_dummies(df_cluster, drop_first = True)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_encoded)

kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# %%
df_cluster['cluster'] = clusters
df_cluster['cluster'].value_counts(normalize=True) * 100
# Out:
# cluster
# 1    33.840166
# 2    29.069303
# 0    22.191268
# 3    14.899263
# Name: proportion, dtype: float64

# %% [markdown]
# * Cluster 1: Perfil dominante
# * Cluster 2: Segundo gran perfil
# * Cluster 0: Perfil no tan relevante
# * Cluster 3: Perfil minoritario

# %% [markdown]
# Al filtrar partiendo de la educacion y grupo de edad, el modelo de clustering identificó perfiles socio-educativos homogéneos y  diferenciados. La proyección mediante PCA evidencia una separación más clara entre clusters, sugiriendo que la edad materna y el nivel educativo son dimensiones estructurantes del fenómeno analizado. A continuacion se explora a que cluster se asocia a determinado perfil:

# %% [markdown]
# ### Interpretación del nivel educativo:

# %%
pd.crosstab(
    df_cluster['cluster'],
    df_cluster['instruccion_madre'],
    normalize='index'
) * 100
# Out:
# instruccion_madre  1.Sin instrucción  2.Primaria/C. EGB Incompleta  \
# cluster
# 0                           0.189675                      2.048299
# 1                           0.192986                      2.361993
# 2                           0.191072                      2.077160
# 3                           0.198046                      2.037250
#
# instruccion_madre  3.Primaria/C. EGB Completa  \
# cluster
# 0                                   13.202972
# 1                                   12.719754
# 2                                   10.948567
# 3                                   10.042085
#
# instruccion_madre  4.Secundaria/Polimodal Incompleta  \
# cluster
# 0                                          31.608330
# 1                                          30.238507
# 2                                          14.793142
# 3                                          12.392422
#
# instruccion_madre  5.Secundaria/Polimodal Completa  \
# cluster
# 0                                        39.705710
# 1                                        35.394627
# 2                                        32.200834
# 3                                        29.073408
#
# instruccion_madre  6.Terciaria/Universitaria Incompleta  \
# cluster
# 0                                              5.494720
# 1                                              5.865872
# 2                                              8.230271
# 3                                              8.546548
#
# instruccion_madre  7.Terciaria/Universitaria Completa  8.Sin especificar
# cluster
# 0                                            2.352366           5.397927
# 1                                            8.034879           5.191383
# 2                                           24.643793           6.915160
# 3                                           32.980443           4.729799

# %% [markdown]
# #### Interpretacion:
# # Cluster 0 (22.2 %)
#  Distribucion:
#
#  * Secundaria completa: 39.7 %
#
#  * Secundaria incompleta: 31.6 %
#
#  * Terciaria / universitaria completa: 2.3 %
#
# **Perfil con concentración mayoritaria en niveles educativos medios**
#
#
# # Cluster 1 (33.8 % – mayoritario)
#  Distribucion:
#
#  * Secundaria incompleta: 30.2 %
#
#  * Secundaria completa: 35.4 %
#
#  * Terciaria / universitaria completa: 8.0 %
#
# **Perfil mixto de educación media con transición a superior**
#
# # Cluster 2 (29.1 %)
# Distribución:
#
# * Secundaria completa: 32.2 %
#
# * Terciaria / universitaria completa: 24.6 %
#
#  * Terciaria / universitaria incompleta: 8.2 %
#
# **Perfil de alta escolaridad**
#
# # Cluster 3 (14.9 % – minoritario)
# Distribución:
#
#  * Terciaria / universitaria completa: 33.0 %
#
#  * Terciaria / universitaria incompleta: 8.5 %
#
#  * Secundaria completa: 29.1 %
#
#
# **Perfil de educación superior consolidada**

# %% [markdown]
# ### Interpretacion de grupo etario:

# %%
tabla_edad = pd.crosstab(
    df_cluster['cluster'],
    df_cluster['edad_madre_grupo'],
    normalize='index'
) * 100

tabla_edad
# Out:
# edad_madre_grupo  1.Menor de 15  2.15 a 19  3.20 a 24  4.25 a 29  5.30 a 34  \
# cluster
# 0                      0.000000   0.000000      100.0   0.000000   0.000000
# 1                      0.627685  25.327948        0.0  74.044368   0.000000
# 2                      0.057471   0.000000        0.0   0.000000  79.492615
# 3                      0.000000   0.000000        0.0   0.000000   0.000000
#
# edad_madre_grupo  6.35 a 39  7.40 a 44  8.De 45 y más  9.Sin especificar
# cluster
# 0                       0.0   0.000000       0.000000           0.000000
# 1                       0.0   0.000000       0.000000           0.000000
# 2                       0.0  15.767161       1.500959           3.181794
# 3                     100.0   0.000000       0.000000           0.000000

# %% [markdown]
# #### Interpretacion:
# # Cluster 0 (22.2 %)
#  Distribucion:
#
#  * 20 a 24 Años = 100%
#
# **Perfil de maternidad temprana-adulta (20-24 años)**
#
#
# # Cluster 1 (33.8 %)
#  Distribucion:
#
#  * 15 a 19 años = 25.3%
#
#  * 25 a 29 años = 74.0%
#
# **Perfil de transición adolescente-adulta (15-29 años)**
#
# # Cluster 2 (29.1 %)
# Distribución:
#
# * 30 a 34 años = 79.5%
#
# * 40 a 44 años = 15.8%
#
#  * 45+ = 1.5%
#
# **Perfil de maternidad adulta **
#
# # Cluster 3 (14.9 % )
# Distribución:
#
#  * 35 a 39 = 100%
#
#
# **Perfil de maternidad tardia**

# %% [markdown]
# ### Grafico K-MEANS

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
df_pca['cluster'] = df_cluster['cluster']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=df_pca,
    x='PC1',
    y='PC2',
    hue='cluster',
    palette='tab10',
    alpha=0.6
)

plt.title('Clusters de perfiles maternos (PCA + KMeans)')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.legend(title='Cluster')
plt.show()

# %% [markdown]
# ## Conclusion - Exploracion mediante k-means
# Mediante la aplicación de un modelo de clustering no supervisado se identificaron cuatro perfiles maternos diferenciados, definidos principalmente por el grupo etario de la madre y caracterizados internamente por su nivel educativo. Los resultados muestran que la edad actúa como la dimensión estructurante de la segmentación, mientras que la educación permite describir la heterogeneidad dentro de cada cluster. La asignación de rangos etarios no contiguos en algunos grupos responde al enfoque de similitud multidimensional del algoritmo y no a inconsistencias del modelo. En conjunto, el clustering aporta una síntesis interpretable de los patrones presentes en los datos y complementa el análisis descriptivo previo desde una perspectiva de ciencia de datos exploratoria.
#
# Se detalla mas en el informe adjunto.
